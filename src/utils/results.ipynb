# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_mrr_results(file):
    # Step 1: Read content from file
    with open(file, 'r') as f:
        data = f.read()

    # Step 2: Parse the content
    lines = [line.strip() for line in data.splitlines() if line.strip()]
    bins = []
    num_docs = []
    mrr = []
    lengths = []

    for line in lines:
        if 'Bin' in line:
            bins.append(line.split('(')[0].strip())
            # Extracting length value and appending it to lengths list
            length_val = line.split('(')[1].split(')')[0].strip()
            lengths.append(length_val)
        elif 'Number of docs' in line:
            num_docs.append(int(line.split(':')[1].strip()))
        elif 'MRR@10' in line:
            mrr.append(float(line.split('=')[1].strip()))

    df = pd.DataFrame({
        'Bin': bins,
        'Length': lengths,
        'Number of docs': num_docs,
        'MRR@10': mrr
    })

    n_docs = sum(df['Number of docs'])

    weighted_mrr = sum(df['MRR@10'] * df['Number of docs'])/n_docs

    print(f'MRR@10: {weighted_mrr}')

    # Step 3: Plotting
    fig, ax1 = plt.subplots(figsize=(12, 7))

    ax2 = ax1.twinx()
    df.plot(x='Bin', y='Number of docs', kind='bar', ax=ax1, position=1, color='blue', legend=False)
    df.plot(x='Bin', y='MRR@10', marker='o', ax=ax2, color='red', legend=False)

    ax1.set_ylabel('Number of docs', color='blue')
    ax2.set_ylabel('MRR@10', color='red')
    ax1.set_xlabel('Bin')
    ax1.set_title('Number of docs and MRR@10 vs Bin')
    plt.show()

# %% [markdown]
# ### MSMARCO_PASSAGE

# %%
plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_by_length_bins_small.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_by_length_bins_small.txt')
#
# Cell In[1], line 24, in plot_mrr_results(file)
#      21     elif 'MRR@10' in line:
#      22         mrr.append(float(line.split('=')[1].strip()))
# ---> 24 df = pd.DataFrame({
#      25     'Bin': bins,
#      26     'Length': lengths,
#      27     'Number of docs': num_docs,
#      28     'MRR@10': mrr
#      29 })
#      31 n_docs = sum(df['Number of docs'])
#      33 weighted_mrr = sum(df['MRR@10'] * df['Number of docs'])/n_docs
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### MSMARCO_PASSAGE_WITH_DOCS

# %%
plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_passage_with_docs.txt')
# Out:
# MRR@10: 0.5711865613210909

# %% [markdown]
# ### MSMARCO_PASSAGE_PREFIX

# %%
plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_passage_prefix.txt')
# Out:
# MRR@10: 0.5662100857552594

# %% [markdown]
# ### MSMARCO_PASSAGE_POSTFIX

# %%
plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_passage_postfix.txt')
# Out:
# MRR@10: 0.5660644631492489

# %% [markdown]
# ### MSMARCO_PASSAGE_RANDOM

# %%
plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_passage_random.txt')
# Out:
# MRR@10: 0.5686935525461109

# %% [markdown]
# ### MSMARCO_DOCS

# %%
plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_by_length_bins_docs.txt')
# Out:
# MRR@10: 0.551915956649766

# %% [markdown]
# ### MSMARCO_DOCS_256_FINETUNED

# %%
plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_by_length_bins_docs_256.txt')
# Out:
# MRR@10: 0.6330962460448931

# %% [markdown]
# ### MSMARCO_DOCS_512_FINETUNED

# %%
plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_by_length_bins_docs_512.txt')
# Out:
# MRR@10: 0.6205360575602794

# %% [markdown]
# ### MSMARCO_DOCS_SPLITTED

# %%
plot_mrr_results('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/results/evaluation_docs_splitted.txt')
# Out:
# MRR@10: 0.6182258852258856
