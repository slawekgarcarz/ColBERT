# %%
import matplotlib.pyplot as plt

def plot_loss(filename):
    # Lists to store the extracted data
    steps = []
    loss_values = []

    # Read the data from the file
    with open(filename, 'r') as file:
        for line in file:
            step, loss = line.split()
            steps.append(int(step))
            loss_values.append(float(loss))

    # Plot the data
    plt.plot(steps, loss_values, '-o')
    plt.xlabel("Step")
    plt.ylabel("Loss")
    plt.title("Loss over Steps")
    plt.grid(True)
    plt.show()

# %%
plot_loss('/gpfs/home3/sgarcarz/PycharmProjects/ColBERT/src/utils/training_loss_256.txt')
