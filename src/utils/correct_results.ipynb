# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_mrr_results(file):
    # Step 1: Read content from file
    with open(file, 'r') as f:
        data = f.read()

    # Step 2: Parse the content
    lines = [line.strip() for line in data.splitlines() if line.strip()]
    bins = []
    num_docs = []
    mrr = []
    lengths = []

    for line in lines:
        if 'Bin' in line:
            bins.append(line.split('(')[0].strip())
            # Extracting length value and appending it to lengths list
            length_val = line.split('(')[1].split(')')[0].strip()
            lengths.append(length_val)
        elif 'Number of docs' in line:
            num_docs.append(int(line.split(':')[1].strip()))
        elif 'MRR@10' in line:
            mrr.append(float(line.split('=')[1].strip()))

    df = pd.DataFrame({
        'Bin': bins,
        'Length': lengths,
        'Number of docs': num_docs,
        'MRR@10': mrr
    })

    n_docs = sum(df['Number of docs'])

    weighted_mrr = sum(df['MRR@10'] * df['Number of docs'])/n_docs

    print(f'MRR@10: {weighted_mrr}')

    # Step 3: Plotting
    fig, ax1 = plt.subplots(figsize=(12, 7))

    ax2 = ax1.twinx()
    df.plot(x='Bin', y='Number of docs', kind='bar', ax=ax1, position=1, color='blue', legend=False)
    df.plot(x='Bin', y='MRR@10', marker='o', ax=ax2, color='red', legend=False)

    ax1.set_ylabel('Number of docs', color='blue')
    ax2.set_ylabel('MRR@10', color='red')
    ax1.set_xlabel('Bin')
    ax1.set_title('Number of docs and MRR@10 vs Bin')
    plt.show()

# %% [markdown]
# ### MSMARCO_PASSAGE

# %%
plot_mrr_results('../correct_results/evaluation_by_length_bins_small.txt')
# Out:
# MRR@10: 0.40427617185681575

# %% [markdown]
# ### MSMARCO_PASSAGE_WITH_DOCS

# %%
plot_mrr_results('../correct_results/evaluation_passage_with_docs.txt')
# Out:
# MRR@10: 0.39696019688228523

# %% [markdown]
# ### MSMARCO_PASSAGE_PREFIX

# %%
plot_mrr_results('../correct_results/evaluation_passage_prefix.txt')
# Out:
# MRR@10: 0.4048149155663426

# %% [markdown]
# ### MSMARCO_PASSAGE_POSTFIX

# %%
plot_mrr_results('../correct_results/evaluation_passage_postfix.txt')
# Out:
# MRR@10: 0.4037633621320824

# %% [markdown]
# ### MSMARCO_PASSAGE_RANDOM

# %%
plot_mrr_results('../correct_results/evaluation_passage_random.txt')
# Out:
# MRR@10: 0.40556632145941296

# %% [markdown]
# ### MSMARCO_DOCS

# %%
# This is for normal docs not finetuned, not splitted
plot_mrr_results('../correct_results/evaluation_by_length_bins_docs.txt')
# Out:
# MRR@10: 0.4026489362729479

# %% [markdown]
# ### MSMARCO_DOCS_WITH_SUM_USING_NOT_FINETUNED_VERSION

# %%
plot_mrr_results('../correct_results/evaluation_passage_sum.txt')
# Out:
# MRR@10: 0.3860438581026823

# %% [markdown]
# ### MSMARCO_DOCS_256_FINETUNED

# %%
plot_mrr_results('../correct_results/evaluation_by_length_bins_docs_256.txt')
# Out:
# MRR@10: 0.5512198565323565

# %% [markdown]
# ### MSMARCO_DOCS_512_FINETUNED

# %%
plot_mrr_results('../correct_results/evaluation_by_length_bins_docs_512.txt')
# Out:
# MRR@10: 0.531925612052731

# %% [markdown]
# ### MSMARCO_DOCS_WITH_SUMMARIES

# %%
plot_mrr_results('../correct_results/evaluation_passage_doc_sum.txt')
# Out:
# MRR@10: 0.5218899044609941

# %% [markdown]
# ### MSMARCO_DOCS_SPLITTED

# %%
plot_mrr_results('../correct_results/evaluation_docs_splitted.txt')
# Out:
# MRR@10: 0.48869488842560455
